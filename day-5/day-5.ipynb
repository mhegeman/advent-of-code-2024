# %%
# First cell - Import any needed libraries and define functions
from functools import cmp_to_key

def read_rules(filename):
    rules = []
    with open(filename, 'r') as file:
        for line in file:
            # Split each line on | and convert both numbers to integers
            num1, num2 = map(int, line.strip().split('|'))
            rules.append((num1, num2))
    return rules

def find_applicable_rules(pages_to_print, rules):
    # Convert pages to a set for O(1) lookup
    pages_set = set(pages_to_print)
    
    # Check each rule
    applicable_rules = []
    for rule in rules:
        if rule[0] in pages_set and rule[1] in pages_set:
            applicable_rules.append(rule)
            
    return applicable_rules

def verify_page_order(pages_to_print, rules):
   # Get positions of each page
   page_positions = {page: index for index, page in enumerate(pages_to_print)}
   
   # Get applicable rules (where both numbers exist in pages_to_print)
   applicable_rules = find_applicable_rules(pages_to_print, rules)
   
   # Check each rule
   for rule in applicable_rules:
       left_page, right_page = rule
       if page_positions[left_page] >= page_positions[right_page]:
           print(f"Rule violation: {left_page} must come before {right_page}")
           return False, None
   
   middle_index = len(pages_to_print) // 2
   middle_value = pages_to_print[middle_index]
   
   print(f"Valid order: {pages_to_print}")
   return True, middle_value


def read_page_orders(filename):
    orders = []
    with open(filename, 'r') as file:
        for line in file:
            order = [int(x) for x in line.strip().split(',')]
            orders.append(order)
    return orders

def compare(item1, item2): 
    x = (item1, item2) # item 1 should be before item2
    if x in rules:
        return -1
    x = (item2, item1) # item 2 should be before item1
    if x in rules:
        return 1
    return 0

# %%
data_file_1 = 'day-5-input.txt'
data_file_2 = 'day-5-input-2.txt'

rules = read_rules(data_file_1)
print(f"Loaded {len(rules)} rules")
# Out:
# Loaded 1176 rules

# %%
# Third cell - Test with your pages
# You can modify this list to test different combinations
pages_to_print = [75,47,61,53,29]
matching_rules = find_applicable_rules(pages_to_print, rules)

print(f"For pages {pages_to_print}, the following rules apply:")
for rule in matching_rules:
    print(f"{rule[0]}|{rule[1]}")

# %%
# Test it
orders = read_page_orders(data_file_2)
rules = read_rules(data_file_1)
total = 0
incorrect_order = []
for order in orders: 
    #print(order)
    x = verify_page_order(order, rules)
    if (x[0] == True):
        total += x[1]
    else: incorrect_order.append(order)
    
total
# Out:
# Rule violation: 75 must come before 87
# Rule violation: 17 must come before 94
# Valid order: [52, 99, 71, 49, 46, 17, 56, 66, 38, 78, 75, 27, 89, 44, 42]
# Rule violation: 42 must come before 13
# Valid order: [94, 48, 89, 42, 13, 37, 36, 12, 55]
# Valid order: [49, 46, 17, 56, 66, 32, 69, 94, 38, 78, 48, 58, 75, 11, 87, 27, 92, 89, 44, 13, 51, 37, 36]
# Rule violation: 98 must come before 96
# Valid order: [24, 57, 28, 52, 99, 71, 63, 49, 46, 17, 56, 66, 32, 69, 94, 38, 78, 58, 75, 11, 87, 27, 92]
# Valid order: [75, 51, 36, 19, 53, 18, 91]
# Valid order: [27, 92, 89, 44, 13, 51, 19, 81, 22]
# Valid order: [98, 24, 57, 28, 52, 99, 49, 66, 32, 78, 87]
# Valid order: [36, 53, 12, 86, 22, 65, 91, 82, 73, 74, 98, 96, 57, 52, 99]
# Rule violation: 73 must come before 74
# Valid order: [53, 86, 39, 18, 47, 74, 96, 57, 28, 52, 71]
# Valid order: [75, 11, 87, 27, 42, 13, 51, 37, 36, 19, 29, 53, 12, 81, 55, 39, 22, 65, 91]
# Valid order: [48, 75, 92, 44, 13, 29, 12, 86, 39, 18, 22]
# Valid order: [73, 98, 71, 49, 17, 56, 66, 69, 38, 78, 58]
# Valid order: [94, 27, 13, 37, 12, 86, 55]
# Rule violation: 55 must come before 39
# Rule violation: 58 must come before 42
# Rule violation: 55 must come before 74
# Rule violation: 94 must come before 13
# Rule violation: 52 must come before 42
# Valid order: [52, 99, 71, 63, 49, 46, 17, 56, 66, 69, 94, 38, 78, 48, 58, 75, 11, 87, 27, 92, 89, 44, 42]
# Rule violation: 52 must come before 69
# Valid order: [55, 39, 18, 22, 65, 91, 82, 47, 74, 96, 57, 28, 52, 99, 71, 49, 17, 56, 66]
# Valid order: [32, 69, 94, 58, 27, 92, 44, 13, 51, 37, 36, 19, 53, 12, 81]
# Valid order: [74, 98, 57, 52, 99, 71, 63, 49, 17, 56, 66, 32, 69, 94, 38, 78, 58, 75, 11]
# Valid order: [55, 39, 18, 22, 65, 91, 82, 96, 24, 57, 28, 52, 99, 71, 63, 46, 66]
# Valid order: [29, 55, 18, 91, 82, 47, 74, 98, 96, 28, 99, 71, 63]
# Valid order: [38, 78, 48, 58, 27, 92, 89, 13, 51, 19, 29, 81, 39]
# Rule violation: 55 must come before 39
# Valid order: [96, 24, 57, 99, 63, 49, 17, 66, 32, 69, 27]
# Rule violation: 53 must come before 71
# Valid order: [78, 48, 58, 75, 11, 92, 89, 44, 37, 53, 81, 39, 18]
# Rule violation: 82 must come before 96
# Rule violation: 17 must come before 94
# Valid order: [42, 37, 36, 29, 53, 12, 81, 86, 18, 22, 65, 91, 82, 74, 98, 96, 24]
# Valid order: [87, 44, 51, 36, 19, 53, 12, 55, 39, 18, 22, 82, 73]
# Valid order: [69, 38, 48, 58, 11, 89, 42, 51, 37, 36, 19, 29, 53, 12, 86]
# Valid order: [24, 99, 71, 56, 66, 94, 38, 75, 11, 27, 92]
# Valid order: [69, 78, 48, 75, 11, 92, 51, 36, 12, 81, 86]
# Rule violation: 27 must come before 51
# Rule violation: 63 must come before 17
# Valid order: [36, 19, 53, 12, 81, 86, 55, 39, 18, 22, 65, 82, 73, 47, 74, 98, 96, 24, 28, 52, 99]
# Valid order: [18, 65, 73, 47, 28, 71, 63, 49, 66, 32, 69]
# Valid order: [53, 12, 55, 39, 18, 22, 65, 91, 73, 47, 96, 28, 99, 63, 49]
# Rule violation: 55 must come before 39
# Rule violation: 17 must come before 48
# Rule violation: 51 must come before 55
# Valid order: [19, 29, 53, 12, 55, 18, 22, 65, 91, 47, 74, 96, 24, 28, 52, 99, 71]
# Valid order: [13, 51, 37, 53, 12, 39, 22, 65, 91, 73, 47, 98, 24]
# Rule violation: 55 must come before 47
# Rule violation: 55 must come before 74
# Valid order: [37, 36, 19, 29, 53, 81, 86, 55, 39, 18, 22, 65, 91, 82, 73, 47, 74, 98, 96, 24, 57, 28, 52]
# Rule violation: 73 must come before 52
# Rule violation: 17 must come before 56
# Rule violation: 53 must come before 12
# Rule violation: 42 must come before 55
# Valid order: [69, 94, 78, 48, 58, 75, 27, 92, 89, 44, 13, 51, 37, 36, 19, 29, 53, 81, 86]
# Valid order: [86, 39, 65, 91, 82, 47, 74, 24, 52, 17, 56]
# Rule violation: 73 must come before 74
# Rule violation: 55 must come before 39
# Rule violation: 18 must come before 22
# Valid order: [52, 99, 71, 63, 49, 56, 66, 32, 69, 94, 38, 48, 58, 75, 11, 87, 27, 92, 89, 44, 42]
# Valid order: [22, 65, 91, 82, 74, 96, 24, 57, 99, 71, 63, 49, 46, 17, 56, 66, 32]
# Valid order: [92, 89, 44, 42, 13, 51, 37, 36, 19, 29, 53, 12, 81, 86, 39, 18, 22, 65, 91, 82, 73, 47, 74]
# Rule violation: 55 must come before 39
# Rule violation: 17 must come before 56
# Rule violation: 55 must come before 39
# Rule violation: 18 must come before 91
# Rule violation: 42 must come before 13
# Rule violation: 55 must come before 39
# Valid order: [87, 27, 89, 44, 13, 37, 36, 53, 12, 81, 86, 55, 18, 91, 73]
# Rule violation: 37 must come before 73
# Rule violation: 55 must come before 74
# Valid order: [22, 65, 91, 73, 74, 98, 24, 28, 52, 99, 49, 46, 56, 66, 94]
# Rule violation: 75 must come before 87
# Rule violation: 55 must come before 91
# Rule violation: 17 must come before 66
# Rule violation: 51 must come before 65
# Rule violation: 52 must come before 32
# Rule violation: 75 must come before 11
# Valid order: [51, 37, 36, 29, 12, 81, 55, 18, 82, 73, 74, 98, 96, 24, 28]
# Valid order: [99, 71, 63, 49, 46, 17, 56, 66, 94, 38, 78, 58, 75, 11, 87, 27, 92, 89, 44, 42, 13]
# Rule violation: 52 must come before 69
# Valid order: [36, 19, 29, 53, 12, 81, 86, 55, 39, 18, 22, 65, 91, 82, 73, 74, 24, 57, 28, 52, 99]
# Valid order: [47, 96, 24, 57, 28, 52, 99, 63, 49, 17, 56, 38, 78, 48, 75]
# Rule violation: 17 must come before 94
# Rule violation: 55 must come before 39
# Rule violation: 52 must come before 69
# Rule violation: 42 must come before 22
# Valid order: [12, 81, 86, 55, 39, 18, 22, 65, 91, 82, 73, 47, 74, 96, 24, 57, 52, 99, 71, 63, 49]
# Rule violation: 18 must come before 22
# Valid order: [56, 32, 69, 94, 48, 11, 92, 44, 51, 37, 53]
# Rule violation: 51 must come before 39
# Valid order: [69, 94, 38, 78, 58, 75, 11, 87, 27, 92, 89, 44, 42, 13, 51, 37, 36, 19, 29, 53, 12, 81, 86]
# Valid order: [81, 22, 24, 52, 99, 46, 17]
# Rule violation: 42 must come before 13
# Valid order: [13, 51, 37, 91, 74]
# Rule violation: 55 must come before 39
# Rule violation: 42 must come before 13
# Rule violation: 65 must come before 73
# Rule violation: 17 must come before 94
# Rule violation: 17 must come before 56
# Rule violation: 55 must come before 47
# Rule violation: 55 must come before 39
# Rule violation: 89 must come before 12
# Rule violation: 17 must come before 56
# Rule violation: 74 must come before 69
# Rule violation: 75 must come before 86
# Rule violation: 22 must come before 47
# Valid order: [28, 63, 17, 48, 27, 92, 44]
# Rule violation: 42 must come before 13
# Rule violation: 52 must come before 58
# Valid order: [44, 13, 12, 81, 55, 39, 65, 47, 74, 98, 96]
# Rule violation: 52 must come before 32
# Valid order: [17, 56, 66, 32, 78, 48, 92, 89, 44, 42, 13, 51, 36, 19, 29]
# Valid order: [17, 66, 32, 94, 38, 87, 89, 13, 37, 19, 29]
# Valid order: [58, 75, 92, 44, 42, 51, 37, 36, 19, 53, 12, 86, 39, 18, 65]
# Rule violation: 17 must come before 66
# Valid order: [75, 11, 87, 89, 51, 19, 53, 55, 91]
# Valid order: [37, 36, 19, 29, 53, 86, 55, 39, 22, 65, 91, 82, 73, 74, 98, 96, 24, 57, 28]
# Rule violation: 37 must come before 96
# Valid order: [22, 91, 82, 98, 57, 46, 94]
# Rule violation: 55 must come before 47
# Valid order: [37, 19, 53, 12, 86, 55, 18, 22, 65, 82, 73, 47, 74, 98, 96, 57, 52]
# Rule violation: 75 must come before 92
# Valid order: [91, 82, 47, 74, 98, 96, 57, 52, 71, 63, 49, 46, 56, 66, 32, 69, 94, 38, 78]
# Valid order: [63, 49, 46, 56, 66, 32, 69, 94, 38, 78, 48, 58, 75, 11, 87, 27, 92, 89, 44, 42, 13, 51, 37]
# Rule violation: 73 must come before 99
# Rule violation: 42 must come before 13
# Rule violation: 78 must come before 53
# Rule violation: 78 must come before 42
# Rule violation: 74 must come before 49
# Valid order: [46, 17, 56, 38, 27, 92, 42, 13, 51, 37, 36]
# Rule violation: 55 must come before 39
# Rule violation: 55 must come before 39
# Rule violation: 73 must come before 57
# Rule violation: 42 must come before 13
# Valid order: [42, 29, 12, 86, 22, 91, 73, 47, 24]
# Rule violation: 17 must come before 48
# Rule violation: 73 must come before 66
# Valid order: [58, 87, 27, 92, 89, 37, 36, 53, 12, 86, 55]
# Valid order: [24, 57, 28, 52, 71, 63, 46, 17, 56, 32, 69, 94, 38, 78, 48, 75, 11, 87, 92]
# Rule violation: 89 must come before 44
# Valid order: [74, 96, 28, 52, 63, 49, 56, 32, 69, 78, 58, 75, 11]
# Rule violation: 17 must come before 94
# Valid order: [57, 28, 52, 99, 49, 46, 56, 66, 69, 38, 78, 48, 58, 11, 87, 92, 89]
# Rule violation: 17 must come before 48
# Rule violation: 44 must come before 37
# Rule violation: 51 must come before 22
# Valid order: [66, 94, 48, 75, 27, 37, 12]
# Valid order: [99, 56, 66, 69, 38, 48, 27, 92, 13]
# Rule violation: 52 must come before 32
# Rule violation: 17 must come before 56
# Rule violation: 75 must come before 92
# Valid order: [46, 17, 56, 32, 69, 94, 38, 58, 75, 11, 27, 92, 89, 13, 51]
# Rule violation: 56 must come before 37
# Rule violation: 55 must come before 39
# Valid order: [87, 27, 92, 89, 42, 13, 51, 19, 29, 53, 12, 81, 55, 39, 65, 82, 73]
# Valid order: [53, 81, 86, 39, 96, 57, 49]
# Rule violation: 17 must come before 94
# Rule violation: 73 must come before 96
# Valid order: [56, 66, 32, 69, 94, 38, 78, 48, 58, 75, 87, 89, 44, 37, 36, 19, 29]
# Valid order: [48, 58, 75, 11, 27, 92, 89, 44, 42, 13, 36, 19, 29, 53, 12, 86, 39, 18, 22]
# Rule violation: 82 must come before 28
# Rule violation: 17 must come before 56
# Valid order: [47, 74, 96, 57, 28, 49, 46, 69, 48, 58, 75]
# Valid order: [22, 74, 98, 96, 24, 28, 71, 63, 94]
# Valid order: [32, 38, 11, 89, 42, 51, 81]
# Valid order: [71, 46, 66, 32, 38, 78, 58, 87, 89, 42, 51]
# Rule violation: 42 must come before 22
# Valid order: [38, 78, 48, 58, 75, 11, 87, 27, 92, 89, 44, 42, 13, 51, 36, 19, 29, 53, 12, 81, 86, 55, 39]
# Valid order: [28, 99, 63, 49, 46, 17, 56, 66, 32, 69, 94, 38, 78, 48, 58, 75, 11, 27, 92, 89, 44]
# Rule violation: 17 must come before 48
# Valid order: [29, 53, 12, 81, 86, 55, 18, 22, 91, 82, 47, 98, 57, 28, 52, 99, 63]
# Rule violation: 73 must come before 57
# Valid order: [87, 13, 37, 12, 86, 91, 73]
# Rule violation: 73 must come before 69
# Rule violation: 18 must come before 24
# Rule violation: 18 must come before 22
# Valid order: [74, 98, 24, 28, 52, 99, 56, 66, 32, 48, 58, 75, 11]
# Valid order: [94, 78, 58, 75, 11, 87, 27, 89, 44, 42, 13, 51, 37, 36, 19, 29, 53, 12, 81, 86, 55]
# Valid order: [42, 51, 37, 53, 12, 81, 86, 39, 18, 91, 73, 47, 74, 96, 24]
# Rule violation: 99 must come before 46
# Valid order: [42, 13, 37, 36, 86, 55, 39, 18, 65, 82, 73, 47, 24]
# Rule violation: 42 must come before 55
# Valid order: [86, 39, 18, 22, 65, 82, 73, 47, 74, 98, 96, 24, 57, 28, 52, 71, 63, 17, 56]
# Rule violation: 12 must come before 47
# Rule violation: 17 must come before 94
# Rule violation: 56 must come before 37
# Rule violation: 52 must come before 44
# Rule violation: 17 must come before 94
# Rule violation: 55 must come before 39
# Rule violation: 55 must come before 39
# Valid order: [19, 53, 81, 39, 65, 74, 57, 52, 71]
# Valid order: [73, 98, 24, 57, 71, 63, 46, 17, 38]
# Rule violation: 75 must come before 87
# Valid order: [13, 51, 37, 36, 19, 29, 53, 12, 81, 86, 55, 39, 18, 22, 65, 91, 82, 73, 47, 74, 96, 24, 57]
# 4766

# %% [markdown]
# # Part 2
#
# Sorting all of the incorrect page orders, then taking the middle value. Probably should test the sort first.

# %%
total_2 = 0
for test in incorrect_order:
    test.sort(key=cmp_to_key(compare))
    middle_index = len(test) // 2
    middle_value = test[middle_index]
    total_2 += middle_value

total_2
# Out:
# 6257
